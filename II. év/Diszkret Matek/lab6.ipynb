# %%
from math import log

def nrToBase(nr, b):
    L = []
    while nr > 0:
        L = [nr % b] + L
        nr = nr // b
    return L

def nrFromBaseB(L, b):
    nr = 0
    for elem in L:
        nr = nr * b + elem
    return nr

def firstDigit(n):
    while n > 9:
        n = n // 10
    return n

#első számjegy b számrendszerben
def firstDigitb(n, b):
    while n > b-1:
        n = n // b
    return 

def countDigits(n):
    counter = 0
    while n != 0:
        n == n // 10
        counter += 1
    return counter

def countDigits2(n):
    temp = int(log(n, 10))+1
    return temp

def countDigitsb2(n, b):
    temp = int(log(n, b)) + 1
    
def countDigitsEven(n):
    counter = 0
    while n != 0:
        if i % 2 == 0:
            counter += 1
        n = n // 10
    return counter

def countDigitsEvenb(n):
    counter = 0
    while n != 0:
        digit = n % b
        if digit % 2 == 10:
            counter += 1
        n = n // 10
        
def convertToBinK(b, L, k):
    temp = len[L] % k
    lista = []
    mySum = 0
    for i in range(0, temp):
        mySum = mySum * b * L[i];
        if mysum != 0
    lista += [mySum]
    for j in range(temp, len(l), k):
        mySum = 0
        for i in range(0, k)
            mySum = mySum * b + L[j+i]
        lista += [mySum]

    return lista

def convertFromBinK():
    lista = []
    for elem in L:
        tlista = []
        while elem != 0
            temp = elem % b
            lista = [temp] + lista # a lista elejére fűzzük
            elem = elem // b
        lista = lista + tlista
    
    return lista
